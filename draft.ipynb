# %%
import numpy as np 
import pandas as pd

# %%
data = pd.read_csv("train.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13174211 entries, 0 to 13174210
# Data columns (total 20 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   session_id      int64
#  1   index           int64
#  2   elapsed_time    int64
#  3   event_name      object
#  4   name            object
#  5   level           int64
#  6   page            float64
#  7   room_coor_x     float64
#  8   room_coor_y     float64
#  9   screen_coor_x   float64
#  10  screen_coor_y   float64
#  11  hover_duration  float64
#  12  text            object
#  13  fqid            object
#  14  room_fqid       object
#  15  text_fqid       object
#  16  fullscreen      float64
#  17  hq              float64
#  18  music           float64
#  19  level_group     object
# dtypes: float64(9), int64(4), object(7)
# memory usage: 2.0+ GB

# %%
data[['elapsed_time','level']].describe()
# Out:
#        elapsed_time         level
# count  1.317421e+07  1.317421e+07
# mean   3.846817e+06  1.219194e+01
# std    2.701387e+07  6.499188e+00
# min    0.000000e+00  0.000000e+00
# 25%    4.394300e+05  6.000000e+00
# 50%    1.013425e+06  1.300000e+01
# 75%    1.740050e+06  1.800000e+01
# max    1.749293e+09  2.200000e+01

# %%
data[['event_name','name','text','fqid','room_fqid','text_fqid','level_group']].describe()
# Out:
#             event_name       name       text     fqid  \
# count         13174211   13174211    4806891  9014563
# unique              11          6        594      127
# top     navigate_click  undefined  undefined   worker
# freq           5687896    6377305     178294   939555
#
#                             room_fqid  \
# count                        13174211
# unique                             19
# top     tunic.historicalsociety.entry
# freq                          1816202
#
#                                          text_fqid level_group
# count                                      4806945    13174211
# unique                                         126           3
# top     tunic.historicalsociety.cage.confrontation       13-22
# freq                                        333363     6746397

# %%
data[['page','room_coor_x','room_coor_y','screen_coor_x','screen_coor_y','hover_duration','fullscreen','hq','music']].describe()
# Out:
#                 page   room_coor_x   room_coor_y  screen_coor_x  \
# count  284746.000000  1.213797e+07  1.213797e+07   1.213797e+07
# mean        3.157930 -5.493615e+01 -1.162997e+02   4.581144e+02
# std         2.064042  5.201468e+02  2.185912e+02   2.472144e+02
# min         0.000000 -1.992355e+03 -9.181587e+02   0.000000e+00
# 25%         1.000000 -3.529376e+02 -2.128361e+02   2.690000e+02
# 50%         3.000000 -1.116317e+01 -9.778151e+01   4.470000e+02
# 75%         5.000000  2.963618e+02  2.268531e+01   6.630000e+02
# max         6.000000  1.261774e+03  5.436164e+02   1.916000e+03
#
#        screen_coor_y  hover_duration  fullscreen   hq  music
# count   1.213797e+07    1.000737e+06         0.0  0.0    0.0
# mean    3.852363e+02    3.186237e+03         NaN  NaN    NaN
# std     1.292879e+02    3.692265e+05         NaN  NaN    NaN
# min     0.000000e+00    0.000000e+00         NaN  NaN    NaN
# 25%     3.040000e+02    1.000000e+02         NaN  NaN    NaN
# ...

# %%
data
# Out:
#                  session_id  index  elapsed_time      event_name       name  \
# 0         20090312431273200      0             0  cutscene_click      basic
# 1         20090312431273200      1          1323    person_click      basic
# 2         20090312431273200      2           831    person_click      basic
# 3         20090312431273200      3          1147    person_click      basic
# 4         20090312431273200      4          1863    person_click      basic
# ...                     ...    ...           ...             ...        ...
# 13174206  22100221145014656   1600       5483231  navigate_click  undefined
# 13174207  22100221145014656   1601       5485166  navigate_click  undefined
# 13174208  22100221145014656   1602       5485917  navigate_click  undefined
# 13174209  22100221145014656   1603       5486753  navigate_click  undefined
# 13174210  22100221145014656   1604       5487952      checkpoint      basic
#
# ...

# %%
indi = pd.DataFrame(data['room_coor_x'])
indi.head(30)
# Out:
#     room_coor_x
# 0   -413.991405
# 1   -413.991405
# 2   -413.991405
# 3   -413.991405
# 4   -412.991405
# 5   -412.991405
# 6    478.485079
# 7    503.355128
# 8    510.733442
# 9    512.048005
# 10   501.110035
# 11   501.084991
# 12   510.081490
# 13   486.877471
# 14   273.991410
# 15   185.708460
# 16     0.583565
# 17   350.344270
# 18   -37.961716
# 19  -133.236752
# 20  -253.401844
# 21  -385.096230
# 22  -564.055739
# 23  -720.325333
# 24  -818.128894
# 25  -924.692590
# 26  -472.142708
# 27  -206.471467
# 28  -587.657879
# 29  -182.558163

# %%
indi = pd.DataFrame(data['level_group'])
indi['level_group'].unique()
# Out:
# array(['0-4', '5-12', '13-22'], dtype=object)
